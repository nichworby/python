# %% [markdown]
# # <font color='blue'> Exploratory Data Analysis with Python: Part 2 of 2</font>

# %% [markdown]
# ### Lise Doucette, Data and Statistics Librarian
# ### Nich Worby, Government Information and Statistics Librarian
# ### mdl@library.utoronto.ca

# %% [markdown]
# # <font color='blue'> Outline </font>

# %% [markdown]
# from our LibCal description: "This is the second of two workshops on exploratory data analysis using Python, and you must have completed Exploratory Data Analysis Using Python – Part 1 of 2, or be familiar with reading, describing, filtering, and summarizing data using the pandas package.
#
# This hands-on workshop in Python uses the pandas package and Jupyter Notebooks to group data, work with date and text formats, recode data, and create new variables. We will be using software installed on computers in the MDL Lab and a sample data set that includes categorical, binary, text, date, and numerical data."
#
#
# In Part 2, we'll cover:
#
# ## <font color='blue'> 7 Creating crosstabs and grouping data </font> (Nich)
# ## <font color='blue'> 8 Editing data / creating new fields </font>
# ### a. Renaming variable categories (Lise)
# ### b. Creating new variable w calculation (Nich)
# ### c. Split name into first and last (Nich)
# ### d. Something with date and time of embarquation (Lise)
# ### e. Binning ages (Lise)
#
# __NOTE: WE NEED TO REVISIT the ORDER OF THINGS HERE
#
#
# ## <font color='blue'> Quick review from Part 1 :</font>  (Nich)
#
# #### <font color='blue'> 1 Overview</font>
# #### <font color='blue'> 2 Import libraries and import your data </font>
# #### <font color='blue'> 3 Getting help </font>
# #### <font color='blue'> 4 Viewing your Data </font>
# #### <font color='blue'> 5 Plotting/Graphing your Data</font>
# #### <font color='blue'> 6 Selecting and filtering your data </font>
#
#
# ---

# %% [markdown]
# ## <font color='blue'> Review and getting data loaded</blue>
#
# PLACEHOLDER: ADD IN ANYTHING YOU WANT TO REVIEW HERE OR CONSIDER DOING IT BEFORE PART 8

# %% [markdown]
# ### import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### import existing data

# %%
titanic = pd.read_csv('titanic.csv', sep=';')

# %% [markdown]
# ### a)  View the first few rows of data

# %% [markdown]
# ## <font color='blue'>7 Creating crosstabs and grouping data</font>

# %% [markdown]
# ### a) Create crosstabs
#
# Things to think about:
# - data types of variables you're interested in
#
# Crosstabs are a way of looking at potential relationships between two or more variables. Variables are plotted against each other in a table with variables on the x and y axes. The cells contain the number of times the a combination of categories occurred. For example:
#
# |   survived    | 0 | 1  |
# | --------------|--------|
# |   pclass      |   |    |
# | ------------- |:--|---:|
# | 1             | 10| 98 |
# | 2             | 78| 50 |
# | 3             | 99| 12 |
#
# The syntax is slightly different than some of the selecting and filtering we did in the previous class. To create a crosstab, use the following syntax:
#
#     pd.crosstab(dataframe.variable, dataframe.variable2)
#
# If ever you have questions about how to use syntax, it's useful to check out the pandas library's [help file](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.crosstab.html). For example, the normalize function creates percentages.
#
#
#
# Also talk about formatting for normalized crosstab – how do you limit the number of decimal points?
# pd.crosstab(df.A,df.B, normalize='index').round(4)*100

# %%
pd.crosstab(titanic.pclass, titanic.survived)
# Out:
# survived    0    1
# pclass
# 1         123  200
# 2         158  119
# 3         528  181

# %% [markdown]
# Use the normalize argument to display crosstab values as percentages

# %%
pd.crosstab(titanic.pclass, titanic.survived, normalize='index')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-31deadd152bb> in <module>()
# ----> 1 pd.crosstab(titanic.pclass, titanic.survived, normalize='index')
#
# NameError: name 'pd' is not defined

# %% [markdown]
# Cross tabs aren't just limited to comparing two variables at a time. Let's say we want to compare passenger class, sex and survival rates. We can use square brackets [ ] to incorporate more variables into the crosstab, similar to earlier exammples.

# %%
pd.crosstab([titanic.pclass, titanic.sex], titanic.survived, normalize='index')
# Out:
# survived              0         1
# pclass sex
# 1      female  0.034722  0.965278
#        male    0.659218  0.340782
# 2      female  0.113208  0.886792
#        male    0.853801  0.146199
# 3      female  0.509259  0.490741
#        male    0.847870  0.152130

# %% [markdown]
# ### b) Grouping Data
#
# - when does it make sense to use sum, mean, value_counts?

# %%
titanic.groupby('pclass').mean()
# Out:
#         survived        age     sibsp     parch       fare        body
# pclass
# 1       0.619195  39.159918  0.436533  0.365325  87.508992  162.828571
# 2       0.429603  29.506705  0.393502  0.368231  21.179196  167.387097
# 3       0.255289  24.816367  0.568406  0.400564  13.302889  155.818182

# %%
titanic.groupby('pclass').sum()
# Out:
#         survived         age  sibsp  parch        fare    body
# pclass
# 1            200  11121.4167    141    118  28265.4043  5699.0
# 2            119   7701.2500    109    102   5866.6374  5189.0
# 3            181  12433.0000    403    284   9418.4452  8570.0

# %%
titanic.groupby('pclass')['survived'].sum()
# Out:
# pclass
# 1    200
# 2    119
# 3    181
# Name: survived, dtype: int64

# %%
titanic.groupby('pclass')['survived'].value_counts()
# Out:
# pclass  survived
# 1       1           200
#         0           123
# 2       0           158
#         1           119
# 3       0           528
#         1           181
# Name: survived, dtype: int64

# %% [markdown]
# ### Exercise
#
# 1. Create a crosstab to show the numbers of men and women who survived.
# 2. Create a table to show the same data using groupby.
#
# Which output is easier to read?

# %%
pd.crosstab(titanic.sex, titanic.survived)
# Out:
# survived    0    1
# sex
# female    127  339
# male      682  161

# %%
titanic.groupby('sex')['survived'].value_counts()
# Out:
# sex     survived
# female  1           339
#         0           127
# male    0           682
#         1           161
# Name: survived, dtype: int64

# %% [markdown]
# ### Review
#
# __Selecting one column:__
#
#     titanic['col_name']
#
# __Selecting multiple columns:__
#
#     titanic[['col1_name','col2_name']]
#
# __Selecting columns by location:__
#
#     titanic.loc[0:10,2:4]
#
#     titanic.iloc[0:10,2:4]
#
#     titanic.loc[0:10,[[2,7]]
#
# __Selecting columns by location & column name:__
#
#     titanic.loc[0:10,['fare','name']
#
# __Filtering by a condition:__
#
#     titanic[titanic['fare'] > 50]
#     titanic[titanic['name'].str.contains("Robert")]
#
# __Combining filters:__
#
#     titanic[(titanic['fare'] > 50) & (titanic['name'].str.contains(r'\bRobert\b'))]
#
#     titanic[(titanic['pclass']==1) | (titanic['pclass']==2)]

# %% [markdown]
# ### Exercise
# Try to find all the single adult female passengers by creating a filter that includes all those over the age of 18 with the title 'Miss' in their name.

# %%
titanic[(titanic['name'].str.contains('Miss') & (titanic['age']>=18))]
# Out:
#       pclass  survived                                          name     sex  \
# 0          1         1                 Allen, Miss. Elisabeth Walton  female
# 6          1         1             Andrews, Miss. Kornelia Theodosia  female
# 13         1         1                  Barber, Miss. Ellen "Nellie"  female
# 18         1         1                         Bazzani, Miss. Albina  female
# 23         1         1                         Bidois, Miss. Rosalie  female
# 24         1         1                             Bird, Miss. Ellen  female
# 28         1         1                        Bissette, Miss. Amelia  female
# 32         1         1                       Bonnell, Miss. Caroline  female
# 33         1         1                      Bonnell, Miss. Elizabeth  female
# 35         1         1                      Bowen, Miss. Grace Scott  female
# 36         1         1                   Bowerman, Miss. Elsie Edith  female
# 44         1         1               Burns, Miss. Elizabeth Margaret  female
# 66         1         1                   Chaudanson, Miss. Victorine  female
# 67         1         1                          Cherry, Miss. Gladys  female
# 73         1         1                          Cleaver, Miss. Alice  female
# 76         1         1                   Compton, Miss. Sara Rebecca  female
# 82         1         1                       Crosby, Miss. Harriet R  female
# 88         1         1                          Daniels, Miss. Sarah  female
# 103        1         1                 Endres, Miss. Caroline Louise  female
# 104        1         1                Eustis, Miss. Elizabeth Mussey  female
# 105        1         0                      Evans, Miss. Edith Corse  female
# 111        1         1                Fortune, Miss. Alice Elizabeth  female
# 112        1         1                    Fortune, Miss. Ethel Flora  female
# 113        1         1                    Fortune, Miss. Mabel Helen  female
# 117        1         1                Francatelli, Miss. Laura Mabel  female
# 122        1         1            Frolicher, Miss. Hedwig Margaritha  female
# 129        1         1                          Geiger, Miss. Amalie  female
# 130        1         1                Gibson, Miss. Dorothy Winifred  female
# 137        1         1                  Graham, Miss. Margaret Edith  female
# 153        1         1                Hays, Miss. Margaret Bechstein  female
# ...      ...       ...                                           ...     ...
# 877        3         0                  Ilmakangas, Miss. Ida Livija  female
# 878        3         0                 Ilmakangas, Miss. Pieta Sofia  female
# 907        3         0                       Jussila, Miss. Katriina  female
# 908        3         0                      Jussila, Miss. Mari Aina  female
# 932        3         0                             Kink, Miss. Maria  female
# 943        3         0                Laitinen, Miss. Kristina Sofia  female
# 947        3         1               Landergren, Miss. Aurora Adelia  female
# 966        3         0         Lindahl, Miss. Agda Thorilda Viktoria  female
# 967        3         0             Lindblom, Miss. Augusta Charlotta  female
# 980        3         1                      Lundin, Miss. Olga Elida  female
# 992        3         0                            Mangan, Miss. Mary  female
# 1008       3         0                      McGowan, Miss. Katherine  female
# 1040       3         1                     Mulvihill, Miss. Bertha E  female
# 1058       3         0                Nieminen, Miss. Manta Josefina  female
# 1060       3         1                   Nilsson, Miss. Berta Olivia  female
# 1061       3         1               Nilsson, Miss. Helmina Josefina  female
# 1067       3         1                      Nysten, Miss. Anna Sofia  female
# 1079       3         1                            Ohman, Miss. Velin  female
# 1086       3         0                           Olsson, Miss. Elina  female
# 1090       3         0                        Oreskovic, Miss. Jelka  female
# 1091       3         0                       Oreskovic, Miss. Marija  female
# 1126       3         0                       Petranec, Miss. Matilda  female
# 1130       3         0               Pettersson, Miss. Ellen Natalia  female
# 1147       3         0  Riihivouri, Miss. Susanna Juhantytar "Sanni"  female
# 1182       3         1              Salkjelsvik, Miss. Anna Kristine  female
# 1205       3         1                     Sjoblom, Miss. Anna Sofia  female
# 1223       3         1               Stanley, Miss. Amy Zillah Elsie  female
# 1227       3         0                   Strandberg, Miss. Ida Sofia  female
# 1260       3         1                       Turja, Miss. Anna Sofia  female
# 1273       3         0            Vander Planke, Miss. Augusta Maria  female
#
#        age  sibsp  parch            ticket      fare        cabin embarked  \
# 0     29.0      0      0             24160  211.3375           B5        S
# 6     63.0      1      0             13502   77.9583           D7        S
# 13    26.0      0      0             19877   78.8500          NaN        S
# 18    32.0      0      0             11813   76.2917          D15        C
# 23    42.0      0      0          PC 17757  227.5250          NaN        C
# 24    29.0      0      0          PC 17483  221.7792          C97        S
# 28    35.0      0      0          PC 17760  135.6333          C99        S
# 32    30.0      0      0             36928  164.8667           C7        S
# 33    58.0      0      0            113783   26.5500         C103        S
# 35    45.0      0      0          PC 17608  262.3750          NaN        C
# 36    22.0      0      1            113505   55.0000          E33        S
# 44    41.0      0      0             16966  134.5000          E40        C
# 66    36.0      0      0          PC 17608  262.3750          B61        C
# 67    30.0      0      0            110152   86.5000          B77        S
# 73    22.0      0      0            113781  151.5500          NaN        S
# 76    39.0      1      1          PC 17756   83.1583          E49        C
# 82    36.0      0      2         WE/P 5735   71.0000          B22        S
# 88    33.0      0      0            113781  151.5500          NaN        S
# 103   38.0      0      0          PC 17757  227.5250          C45        C
# 104   54.0      1      0             36947   78.2667          D20        C
# 105   36.0      0      0          PC 17531   31.6792          A29        C
# 111   24.0      3      2             19950  263.0000  C23 C25 C27        S
# 112   28.0      3      2             19950  263.0000  C23 C25 C27        S
# 113   23.0      3      2             19950  263.0000  C23 C25 C27        S
# 117   30.0      0      0          PC 17485   56.9292          E36        C
# 122   22.0      0      2             13568   49.5000          B39        C
# 129   35.0      0      0            113503  211.5000         C130        C
# 130   22.0      0      1            112378   59.4000          NaN        C
# 137   19.0      0      0            112053   30.0000          B42        S
# 153   24.0      0      0             11767   83.1583          C54        C
# ...    ...    ...    ...               ...       ...          ...      ...
# 877   27.0      1      0  STON/O2. 3101270    7.9250          NaN        S
# 878   25.0      1      0  STON/O2. 3101271    7.9250          NaN        S
# 907   20.0      1      0              4136    9.8250          NaN        S
# 908   21.0      1      0              4137    9.8250          NaN        S
# 932   22.0      2      0            315152    8.6625          NaN        S
# 943   37.0      0      0              4135    9.5875          NaN        S
# 947   22.0      0      0            C 7077    7.2500          NaN        S
# 966   25.0      0      0            347071    7.7750          NaN        S
# 967   45.0      0      0            347073    7.7500          NaN        S
# 980   23.0      0      0            347469    7.8542          NaN        S
# 992   30.5      0      0            364850    7.7500          NaN        Q
# 1008  35.0      0      0              9232    7.7500          NaN        Q
# 1040  24.0      0      0            382653    7.7500          NaN        Q
# 1058  29.0      0      0           3101297    7.9250          NaN        S
# 1060  18.0      0      0            347066    7.7750          NaN        S
# 1061  26.0      0      0            347470    7.8542          NaN        S
# 1067  22.0      0      0            347081    7.7500          NaN        S
# 1079  22.0      0      0            347085    7.7750          NaN        S
# 1086  31.0      0      0            350407    7.8542          NaN        S
# 1090  23.0      0      0            315085    8.6625          NaN        S
# 1091  20.0      0      0            315096    8.6625          NaN        S
# 1126  28.0      0      0            349245    7.8958          NaN        S
# 1130  18.0      0      0            347087    7.7750          NaN        S
# 1147  22.0      0      0           3101295   39.6875          NaN        S
# 1182  21.0      0      0            343120    7.6500          NaN        S
# 1205  18.0      0      0           3101265    7.4958          NaN        S
# 1223  23.0      0      0          CA. 2314    7.5500          NaN        S
# 1227  22.0      0      0              7553    9.8375          NaN        S
# 1260  18.0      0      0              4138    9.8417          NaN        S
# 1273  18.0      2      0            345764   18.0000          NaN        S
#
#      boat  body                          home.dest
# 0       2   NaN                       St Louis, MO
# 6      10   NaN                         Hudson, NY
# 13      6   NaN                                NaN
# 18      8   NaN                                NaN
# 23      4   NaN                                NaN
# 24      8   NaN                                NaN
# 28      8   NaN                                NaN
# 32      8   NaN                     Youngstown, OH
# 33      8   NaN  Birkdale, England Cleveland, Ohio
# 35      4   NaN                    Cooperstown, NY
# 36      6   NaN   St Leonards-on-Sea, England Ohio
# 44      3   NaN                                NaN
# 66      4   NaN                                NaN
# 67      8   NaN                    London, England
# 73     11   NaN                                NaN
# 76     14   NaN                       Lakewood, NJ
# 82      7   NaN                      Milwaukee, WI
# 88      8   NaN                                NaN
# 103     4   NaN                       New York, NY
# 104     4   NaN                      Brookline, MA
# 105   NaN   NaN                       New York, NY
# 111    10   NaN                       Winnipeg, MB
# 112    10   NaN                       Winnipeg, MB
# 113    10   NaN                       Winnipeg, MB
# 117     1   NaN                                NaN
# 122     5   NaN                Zurich, Switzerland
# 129     4   NaN                                NaN
# 130     7   NaN                       New York, NY
# 137     3   NaN                      Greenwich, CT
# 153     7   NaN                       New York, NY
# ...   ...   ...                                ...
# 877   NaN   NaN                                NaN
# 878   NaN   NaN                                NaN
# 907   NaN   NaN                                NaN
# 908   NaN   NaN                                NaN
# 932   NaN   NaN                                NaN
# 943   NaN   NaN                                NaN
# 947    13   NaN                                NaN
# 966   NaN   NaN                                NaN
# 967   NaN   NaN                                NaN
# 980    10   NaN                                NaN
# 992   NaN  61.0                                NaN
# 1008  NaN   NaN                                NaN
# 1040   15   NaN                                NaN
# 1058  NaN   NaN                                NaN
# 1060    D   NaN                                NaN
# 1061   13   NaN                                NaN
# 1067   13   NaN                                NaN
# 1079    C   NaN                                NaN
# 1086  NaN   NaN                                NaN
# 1090  NaN   NaN                                NaN
# 1091  NaN   NaN                                NaN
# 1126  NaN   NaN                                NaN
# 1130  NaN   NaN                                NaN
# 1147  NaN   NaN                                NaN
# 1182    C   NaN                                NaN
# 1205   16   NaN                                NaN
# 1223    C   NaN                                NaN
# 1227  NaN   NaN                                NaN
# 1260   15   NaN                                NaN
# 1273  NaN   NaN                                NaN
#
# [143 rows x 14 columns]

# %% [markdown]
# ## <font color='blue'>8 Editing data and creating new fields</font>
#
# ### a. Renaming variable categories
#
# Often variables in datasets use codes that aren't very descriptive. It's helpful to first view all codes in a variable before editing.

# %%
titanic['embarked'].value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: embarked, dtype: int64

# %% [markdown]
# Next, read the codebook to understand what the codes mean. There are 3 codes for embarkation points: S = Southampton, C = Cherbourg and Q = Queenstown. Start the next line with the name of the variable you would like to edit, e.g. titanic['embarked'].
#
# Use the = sign next to make sure you write the change to the entire variable and save it. This is similar to value assignment in algebra, e.g. x = y + z.
#
# We can use the .replace( ) method to change our codes to names. We can use .value_counts( ) to check our work.

# %%
titanic['embarked'] = titanic['embarked'].replace(['S', "C", "Q"], ["Southampton", "Cherbourg", "Queenstown"])

# %%
titanic['embarked'].value_counts()
# Out:
# Southampton    914
# Cherbourg      270
# Queenstown     123
# Name: embarked, dtype: int64

# %% [markdown]
# ### b. Creating new variables
#
# The syntax for creating new variables in a dataframe starts by calling the dataframe by name and placing the variable name is square brackets in quotes and assigning value with an equal sign. e.g. dataframe['new variable'] = value.
#
# Let's say we want to calculate the fare variable in Canadian dollars. In 1912, the value of the Canadian dollar was pegged at 4.8666CAD to one British Pound Sterling.

# %%
titanic['fare_CAD'] = titanic['fare']*4.8666

# %% [markdown]
# Check if the new variable has been added by using the .head( ) method.

# %%
titanic.head()

# %% [markdown]
# ### c. Splitting First and Last Name

# %% [markdown]
# ### d. Adding in dates of departure as new variable

# %% [markdown]
# ### e. creating age bins
#
# Just a thought about the age bins: Might this be a good time to review some plotting to demonsrate why we might want to do some binning?

# %% [markdown]
# ## Exercise
#
# Create a new variable called 'is_child'. Filter the data for all passengers under the age of 18 and assign the results to the new variable. Check your new variable using .value_counts(). Next, do a crosstab to check survival rates for children vs. adults. **Bonus:** Add pclass to the crosstab to see how many children and adults in first, second, and third class survived or perished.
#
# __PLACEHOLDER: Scaffold into 3 code blocks with some instruction e.g. first do x.__

# %%
## solution titanic['is_child'] = titanic['age'] < 18

# %%
## solution titanic['is_child'].value_counts()

# %%
## solution pd.crosstab(titanic.is_child, titanic.survived)

# %% [markdown]
# ## <font color='blue'>7 Getting help</font>
#
# quick review from Part 1?
